# %%
# Out:
# Test Height: 175
# Membership in Tall: 0.5
# Membership in Medium: 0.5
# Test Height: 178
# Membership in Tall: 0.8
# Membership in Medium: 0.2
# Test Height: 190
# Membership in Tall: 0.0
# Membership in Medium: 0.0
# Test Height: 182
# Membership in Tall: 0.8
# Membership in Medium: 0.0
# Gayatri Kulkarni -53004230002
